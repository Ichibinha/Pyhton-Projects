# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# TENTATIVA 1
# def f(lx, ly, lz):
#     return lx**2+ly**2+lz**2-4
#
# x = np.linspace(-10, 10, 10)
# y = np.linspace(-10, 10, 10)
# z = np.linspace(-10, 10, 10)
#
#
#
# plt.plot(f(x, y, z))
# plt.grid()
# plt.show()

# %% [markdown]
# TENTATIVA 2
# #declarando a figura
# fig = plt.figure()
# graf = fig.gca(projection='3d')
#
# #variaveis
# #linspace(p0, p, numero de pontos)
# z = np.linspace(-10, 10, 100)
# y = np.linspace(-10, 10, 100)
# x = np.sqrt(-y**2-z**2+4)
#
# #Plotando
# graf.plot(x, y, z, color='red')
# plt.show()

# %%
#Tentativa 4, coordenadas esféricas


#arange(p0, p, intervals)
theta = np.arange(0, 2*np.pi, 0.01)
phi = np.arange(0, np.pi, 0.01)
r = np.sqrt(4)

#meshgrid?
theta, phi = np.meshgrid(theta, phi)

#vinculando as coordenadas cartesianas e esféricas
x = r * np.sin(phi) * np.cos(theta)
y = r * np.sin(phi) * np.sin(theta)
z = r * np.cos(phi)

#criando a figura
fig = plt.figure()
ax = Axes3D(fig)

#plotando a figura
ax.plot_surface(x,y,z, color = 'red', alpha = 0.5)
ax.plot_wireframe(x,y,z, color = 'black', alpha = 0.7)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-33-db183d857b29>:20: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
